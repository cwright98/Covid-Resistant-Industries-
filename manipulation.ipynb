# %%
import pandas as pd

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
url='https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'

# %%
#from Johns Hopkins Github page
worldCovidConfirmed=pd.read_csv(url)

# %%
worldCovidConfirmed.to_csv('worldCovidConfirmed.csv')

# %%
stockPrices=pd.read_csv(r'stock_prices_latest.csv')

# %%
# from: https://www.kaggle.com/tsaustin/us-historical-stock-prices-with-earnings-data?
stockPrices['date']=pd.to_datetime(stockPrices['date']) 
stockPrices=stockPrices.loc[stockPrices['date']>'2017-12-31']
stockPrices.set_index('symbol')
# Out:
#              date     open     high      low    close  close_adjusted  \
# symbol
# MSFT   2018-01-03  86.0550  86.5100  85.9700  86.3500         86.3500
# MSFT   2018-01-16  90.1000  90.7900  88.0104  88.3500         88.3500
# MSFT   2018-01-18  89.8000  90.6700  89.6600  90.1000         90.1000
# MSFT   2018-01-02  86.1250  86.3100  85.5000  85.9500         85.9500
# MSFT   2018-01-19  90.1400  90.6100  89.6600  90.0000         90.0000
# ...           ...      ...      ...      ...      ...             ...
# MTNB   2020-09-22   0.7995   0.8098   0.7723   0.7953          0.7953
# MTNB   2020-09-23   0.8097   0.8100   0.7820   0.7929          0.7929
# MTNB   2020-09-16   0.8000   0.8100   0.7590   0.7784          0.7784
# MTNB   2020-09-17   0.7784   0.8000   0.7553   0.7961          0.7961
# MTNB   2020-09-18   0.8100   0.8100   0.7800   0.8038          0.8038
#
#           volume  split_coefficient
# symbol
# MSFT    24173064                1.0
# ...

# %%
stockPrices['symbol'].astype(str)
# Out:
# 103         MSFT
# 169         MSFT
# 575         MSFT
# 853         MSFT
# 904         MSFT
#             ...
# 22824528    MTNB
# 22824529    MTNB
# 22824530    MTNB
# 22824531    MTNB
# 22824532    MTNB
# Name: symbol, Length: 4198410, dtype: object

# %%
constituents=pd.read_csv(r'constituents_csv.csv')

# %%
constituents.set_index('Symbol', inplace=True)

# %%
constituents.index.names=['symbol']

# %%
constituents.astype(str)
# Out:
#                           Name                  Sector
# symbol
# MMM                 3M Company             Industrials
# AOS            A.O. Smith Corp             Industrials
# ABT        Abbott Laboratories             Health Care
# ABBV               AbbVie Inc.             Health Care
# ABMD               ABIOMED Inc             Health Care
# ...                        ...                     ...
# YUM            Yum! Brands Inc  Consumer Discretionary
# ZBRA        Zebra Technologies  Information Technology
# ZBH     Zimmer Biomet Holdings             Health Care
# ZION             Zions Bancorp              Financials
# ZTS                     Zoetis             Health Care
#
# [505 rows x 2 columns]

# %%
stockIndustry=stockPrices.merge(constituents, on='symbol', how='left')

# %%
tickerIndustry=constituents.to_csv(r'tickerIndustry.csv')

# %%
tickerIndustry=pd.read_csv(r'tickerIndustry.csv')

# %%
tickerIndustry.head()
# Out:
#   symbol                 Name       Sector
# 0    MMM           3M Company  Industrials
# 1    AOS      A.O. Smith Corp  Industrials
# 2    ABT  Abbott Laboratories  Health Care
# 3   ABBV          AbbVie Inc.  Health Care
# 4   ABMD          ABIOMED Inc  Health Care

# %%
import pandas as pd
coviddf=pd.read_csv(r'worldCovidConfirmed.csv')

# %%
coviddf.head()
# Out:
#    Unnamed: 0 Province/State Country/Region       Lat       Long  1/22/20  \
# 0           0            NaN    Afghanistan  33.93911  67.709953        0
# 1           1            NaN        Albania  41.15330  20.168300        0
# 2           2            NaN        Algeria  28.03390   1.659600        0
# 3           3            NaN        Andorra  42.50630   1.521800        0
# 4           4            NaN         Angola -11.20270  17.873900        0
#
#    1/23/20  1/24/20  1/25/20  1/26/20  ...  9/17/20  9/18/20  9/19/20  \
# 0        0        0        0        0  ...    38872    38883    38919
# 1        0        0        0        0  ...    11948    12073    12226
# 2        0        0        0        0  ...    49194    49413    49623
# 3        0        0        0        0  ...     1483     1564     1564
# 4        0        0        0        0  ...     3789     3848     3901
#
#    9/20/20  9/21/20  9/22/20  9/23/20  9/24/20  9/25/20  9/26/20
# ...

# %%
from sqlalchemy import create_engine
import psycopg2
engine = create_engine('postgresql://postgres:Clover98!@localhost:127.0.0.1:58128/Covid_Resistant_Industries')
coviddf.to_sql('table_name', engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-e498470c2789> in <module>
#       1 from sqlalchemy import create_engine
#       2 import psycopg2
# ----> 3 engine = create_engine('postgresql://postgres:Clover98!@localhost:127.0.0.1:58128/Covid_Resistant_Industries')
#       4 coviddf.to_sql('table_name', engine)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     477     strategy = kwargs.pop("strategy", default_strategy)
#     478     strategy = strategies.strategies[strategy]
# --> 479     return strategy.create(*args, **kwargs)
#     480
#     481
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      52     def create(self, name_or_url, **kwargs):
#      53         # create url.URL object
# ...
